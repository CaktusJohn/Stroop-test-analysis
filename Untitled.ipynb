# %% [markdown]
# # Построение гистограмм

# %% [markdown]
# Подключение библиотек

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Чтение таблицы из файла с помощью pandas

# %%
file_path="D:\\AI\\HIstogram\\dataset_mental_report_new.xlsx"
data=pd.read_excel(file_path)

# %% [markdown]
# Вывод таблицы

# %%
data
# Out:
#      Unnamed: 0  num  marker_data_id    apway_id context   person gender  old  \
# 0             0    1           65787  1220_11316   Sofia      201      М   35
# 1             1    2           65810  1226_11325   Sofia      105      М   56
# 2             2    3           66190  1242_11509   Sofia      106      М   60
# 3             3    4           66519  1258_11745   Sofia  001test      Ж   23
# 4             4    5           66555  1256_11772   Sofia      107      Ж   77
# ..          ...  ...             ...         ...     ...      ...    ...  ...
# 414         414  417          264116  5645_46265       1     eka4      Ж   60
# 415         415  418          264139  5623_46271       1      eka      Ж   29
# 416         416  419          264233  5642_46347       1     eka3      Ж   45
# 417         417  420          264269  5623_46352       1      eka      Ж   29
# 418         418  421          264276  5666_46354       1    eka10      М   20
#
#     old_group  stroop_duration  ...  HF_per    FR    SN     Q1     Q2    Q3  \
# 0       22_35              268  ...   23.18  2.49 -1.03  100.0    0.0   0.0
# 1       36_60              836  ...   74.89  0.47  1.74    0.0   78.4  21.6
# 2       36_60              602  ...   26.65 -0.03  0.85    2.0   62.7  33.3
# 3       22_35              136  ...    5.84 -0.42  0.65    0.0   50.0  50.0
# 4     60_PLUS              472  ...   70.93  0.66  2.08    0.0  100.0   0.0
# ..        ...              ...  ...     ...   ...   ...    ...    ...   ...
# 414     36_60              253  ...   33.03  0.36  1.56    0.0   68.8  31.2
# 415     22_35              139  ...   22.11 -0.55  1.18    0.0   25.0  75.0
# 416     36_60              236  ...   15.65  1.24  0.88    0.0  100.0   0.0
# 417     22_35              128  ...   31.79  1.02  0.67    0.0  100.0   0.0
# 418     17_21              156  ...   16.48  0.64  1.21    0.0  100.0   0.0
#
#       Q4  Q_common  adapt_risk  Q_edit
# 0    0.0        Q1           1       0
# 1    0.0        Q2           6       0
# 2    2.0        Q3           6       0
# 3    0.0        Q3           7       0
# 4    0.0        Q2           5       0
# ..   ...       ...         ...     ...
# 414  0.0        Q2           6       0
# 415  0.0        Q3           7       0
# 416  0.0        Q2           5       0
# 417  0.0        Q2           5       0
# 418  0.0        Q2           5       0
#
# [419 rows x 52 columns]

# %% [markdown]
# Выбор только нужных данных

# %%
necessary=data[['gender','old']]
necessary.head()
# Out:
#   gender  old
# 0      М   35
# 1      М   56
# 2      М   60
# 3      Ж   23
# 4      Ж   77

# %% [markdown]
# Фильтрация данных и разделение по полу.(pandas)

# %%
men=necessary[necessary['gender']=='М']['old']
women=necessary[necessary['gender']=='Ж']['old']

# %% [markdown]
# Создание графиков (matplotlib)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)  #таблица из 2 столбцов ,1 строки, работа с 1 ячейкой 
plt.hist(men,bins=8,label='Мужчины',color='blue')
plt.xlabel('Возраст')  
plt.ylabel('Количество')  
plt.legend(loc='upper right')  # Легенда


plt.subplot(1,2,2)
plt.hist(women,bins=8,label='Женщины',color='pink')
plt.xlabel('Возраст')  
plt.ylabel('Количество')  
plt.legend(loc='upper right')
